# %%
from bar_and_line_plot import plot_bar_and_line
from heatmap import plot_housing_affordability
from five_city_line_plot import plot_affordability_vs_time
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('resources/data_interpolated.csv')
#1) new york, chicago, los angeles, dallas, houston
#2) omaha nebraska, boysie idaho, minapolis minnesota, Atlanta georgia, Phenix arizona

# %%
cities = ['Omaha', 'Tampa', 'Minneapolis', 'Atlanta', 'Phoenix']
plot_affordability_vs_time(*cities)

# %%
df_Boise = df[df['CityName'] == 'Tampa']
df_Boise.head()
# Out:
#             Date CityName StateName  MedianSalePrice    Year  MedianListPrice  \
# 18    2008-02-29    Tampa        FL         161500.0  2008.0              NaN
# 693   2008-03-31    Tampa        FL         167100.0  2008.0              NaN
# 1368  2008-04-30    Tampa        FL         162500.0  2008.0              NaN
# 2043  2008-05-31    Tampa        FL         165000.0  2008.0              NaN
# 2718  2008-06-30    Tampa        FL         165000.0  2008.0              NaN
#
#       SalesTotal  Total Population  Median Income  MORTGAGE30US  \
# 18        2099.0               NaN            NaN           NaN
# 693       2524.0               NaN            NaN           NaN
# 1368      2810.0               NaN            NaN           NaN
# 2043      2844.0               NaN            NaN           NaN
# 2718      2935.0               NaN            NaN           NaN
#
#       Unemployment Rate  HAI
# 18                  NaN  NaN
# 693                 NaN  NaN
# ...
